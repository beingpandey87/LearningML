# %% [markdown]
# About this file
#
# Suggest Edits
# The Heart Disease Prediction Dataset is a synthetic medical dataset created for machine learning, data analysis, and predictive modeling tasks. The dataset contains 1000 patient records with multiple health-related features including glucose level, cholesterol level, blood pressure, BMI, heart rate, lifestyle habits, and family medical history.
#
# The primary objective of this dataset is to predict the likelihood of heart disease risk using various clinical and lifestyle indicators. The target column (disease) is designed for binary classification tasks and contains two classes: Yes and No.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from sklearn.model_selection import train_test_split,GridSearchCV,StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score

# %%
df=pd.read_csv("disease_prediction.csv")
df.head()
# Out:
#    patient_id  age  gender  glucose_mg_dl  cholesterol_mg_dl  systolic_bp  \
# 0           1   32    Male            101                235          152
# 1           2   31    Male            124                191          134
# 2           3   45    Male             57                141          114
# 3           4   75  Female             69                268          120
# 4           5   53    Male            107                163          131
#
#    diastolic_bp   bmi  heart_rate smoking alcohol_consumption  \
# 0            79  28.5          73      No                 Yes
# 1            77  33.9          71      No                 Yes
# 2            71  27.2          79     Yes                 Yes
# 3            82  21.5          61     Yes                 Yes
# 4            75  23.3          73     Yes                  No
#
#   physical_activity family_history disease
# 0               Low            Yes     Yes
# 1               Low            Yes     Yes
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   patient_id           1000 non-null   int64
#  1   age                  1000 non-null   int64
#  2   gender               1000 non-null   object
#  3   glucose_mg_dl        1000 non-null   int64
#  4   cholesterol_mg_dl    1000 non-null   int64
#  5   systolic_bp          1000 non-null   int64
#  6   diastolic_bp         1000 non-null   int64
#  7   bmi                  1000 non-null   float64
#  8   heart_rate           1000 non-null   int64
#  9   smoking              1000 non-null   object
#  10  alcohol_consumption  1000 non-null   object
#  11  physical_activity    1000 non-null   object
#  12  family_history       1000 non-null   object
#  13  disease              1000 non-null   object
# dtypes: float64(1), int64(7), object(6)
# memory usage: 109.5+ KB

# %%
df.shape
# Out:
# (1000, 14)

# %%
df.columns
# Out:
# Index(['patient_id', 'age', 'gender', 'glucose_mg_dl', 'cholesterol_mg_dl',
#        'systolic_bp', 'diastolic_bp', 'bmi', 'heart_rate', 'smoking',
#        'alcohol_consumption', 'physical_activity', 'family_history',
#        'disease'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# patient_id             0
# age                    0
# gender                 0
# glucose_mg_dl          0
# cholesterol_mg_dl      0
# systolic_bp            0
# diastolic_bp           0
# bmi                    0
# heart_rate             0
# smoking                0
# alcohol_consumption    0
# physical_activity      0
# family_history         0
# disease                0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
for column in df.columns:    
    print(f"{column} Nan value counts:",df[df[column].isna()].count())
    print("\n")
# Out:
# patient_id Nan value counts: patient_id             0
# age                    0
# gender                 0
# glucose_mg_dl          0
# cholesterol_mg_dl      0
# systolic_bp            0
# diastolic_bp           0
# bmi                    0
# heart_rate             0
# smoking                0
# alcohol_consumption    0
# physical_activity      0
# family_history         0
# disease                0
# dtype: int64
#
#
# age Nan value counts: patient_id             0
# age                    0
# gender                 0
# glucose_mg_dl          0
# cholesterol_mg_dl      0
# systolic_bp            0
# diastolic_bp           0
# bmi                    0
# heart_rate             0
# smoking                0
# alcohol_consumption    0
# physical_activity      0
# family_history         0
# disease                0
# dtype: int64
#
#
# gender Nan value counts: patient_id             0
# age                    0
# gender                 0
# glucose_mg_dl          0
# ...

# %%
df.describe()
# Out:
#         patient_id          age  glucose_mg_dl  cholesterol_mg_dl  \
# count  1000.000000  1000.000000    1000.000000        1000.000000
# mean    500.500000    51.190000     104.163000         210.014000
# std     288.819436    19.847514      25.076508          39.749111
# min       1.000000    18.000000      30.000000          89.000000
# 25%     250.750000    33.000000      87.000000         183.000000
# 50%     500.500000    52.500000     105.000000         210.500000
# 75%     750.250000    69.000000     121.000000         235.250000
# max    1000.000000    85.000000     184.000000         339.000000
#
#        systolic_bp  diastolic_bp          bmi   heart_rate
# count  1000.000000   1000.000000  1000.000000  1000.000000
# mean    123.893000     81.032000    26.093000    75.968000
# std      18.701211      9.969974     4.758282     9.902982
# min      67.000000     49.000000    16.000000    47.000000
# 25%     111.000000     74.000000    22.900000    70.000000
# ...

# %%
df.physical_activity.value_counts()
# Out:
# physical_activity
# Medium    344
# High      344
# Low       312
# Name: count, dtype: int64

# %%
#convering the categorical data into numerical data

#Column with binary categorical data can be converted into numerical data using map function
df["gender"]=df["gender"].map({"Male":1,"Female":0})
df["smoking"]=df["smoking"].map({"Yes":1,"No":0})
df["alcohol_consumption"]=df["alcohol_consumption"].map({"Yes":1,"No":0})
df["family_history"]=df["family_history"].map({"Yes":1,"No":0})

#Columns with more than two categories can be converted into numerical data using get_dummies function
df=pd.get_dummies(df,columns=["physical_activity"],drop_first=True)

# %%
#dividing the data into features and target
X=df.drop("disease",axis=1)
y=df["disease"]   
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=42)

# %%
logistic=LogisticRegression(max_iter=10000)
logistic.fit(X_train,y_train)
y_pred=logistic.predict(X_test)

# %%
print(y_pred)
# Out:
# ['No' 'No' 'No' 'Yes' 'No' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'No' 'Yes' 'No'
#  'No' 'No' 'No' 'No' 'No' 'Yes' 'Yes' 'Yes' 'No' 'Yes' 'No' 'Yes' 'Yes'
#  'No' 'No' 'No' 'No' 'Yes' 'Yes' 'No' 'Yes' 'No' 'No' 'Yes' 'No' 'Yes'
#  'Yes' 'No' 'Yes' 'Yes' 'Yes' 'No' 'No' 'No' 'No' 'Yes' 'No' 'Yes' 'No'
#  'No' 'No' 'Yes' 'No' 'No' 'No' 'No' 'Yes' 'Yes' 'Yes' 'Yes' 'No' 'No'
#  'Yes' 'Yes' 'No' 'Yes' 'Yes' 'No' 'No' 'Yes' 'Yes' 'No' 'No' 'No' 'Yes'
#  'Yes' 'Yes' 'No' 'No' 'Yes' 'No' 'Yes' 'No' 'Yes' 'No' 'No' 'No' 'Yes'
#  'Yes' 'Yes' 'Yes' 'No' 'No' 'Yes' 'No' 'No' 'Yes' 'No' 'Yes' 'No' 'No'
#  'Yes' 'No' 'Yes' 'No' 'Yes' 'No' 'No' 'Yes' 'Yes' 'Yes' 'No' 'No' 'No'
#  'No' 'Yes' 'No' 'Yes' 'No' 'No' 'No' 'No' 'Yes' 'No' 'No' 'Yes' 'Yes'
#  'Yes' 'No' 'No' 'No' 'No' 'No' 'Yes' 'Yes' 'No' 'Yes' 'No' 'Yes' 'Yes'
#  'No' 'Yes' 'No' 'No' 'Yes' 'Yes' 'No' 'No' 'No' 'No' 'Yes' 'Yes' 'Yes'
#  'No' 'No' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'Yes' 'No' 'Yes' 'No' 'No' 'No'
# ...

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.83      0.88      0.86       153
#          Yes       0.87      0.82      0.84       147
#
#     accuracy                           0.85       300
#    macro avg       0.85      0.85      0.85       300
# weighted avg       0.85      0.85      0.85       300

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[135  18]
#  [ 27 120]]

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.85

# %% [markdown]
# # Hyper parameter tuning and Cross Validation

# %%
new_model=LogisticRegression(max_iter=10000)
penalty=["l1","l2","elasticnet"]
c_values=[0.01,0.1,1,10,100]
solver=["liblinear","saga","lbfgs","newton-cg","sag"]

#creating a dictionary to store the hyperparameters
param=dict(penalty=penalty, C=c_values, solver=solver)

# %%
MY_CV=StratifiedKFold(n_splits=5,shuffle=False)

# %%
# Grid Search CV

grid=GridSearchCV(estimator=new_model,param_grid=param,cv=MY_CV, scoring="accuracy")
grid.fit(X_train,y_train)
# Out:
# c:\Users\123456\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:516: FitFailedWarning:
# 200 fits failed out of a total of 375.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 25 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\123456\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\123456\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py", line 1365, in wrapper
#     return fit_method(estimator, *args, **kwargs)
# ...

# %%
grid.best_params_
# Out:
# {'C': 1, 'penalty': 'l2', 'solver': 'newton-cg'}

# %%
grid.best_score_
# Out:
# np.float64(0.8385714285714286)

# %%
y_prep=grid.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.83      0.88      0.86       153
#          Yes       0.87      0.82      0.84       147
#
#     accuracy                           0.85       300
#    macro avg       0.85      0.85      0.85       300
# weighted avg       0.85      0.85      0.85       300

# %%
print(accuracy_score(y_test,y_pred))
# Out:
# 0.85

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[135  18]
#  [ 27 120]]
